# %% [markdown]
# #  Тестируем создание сделки через Битрикс24 API

# %%
# !pip install bitrix24-rest

# %%
import requests
import yaml
import json
from bs4 import BeautifulSoup
from bitrix24 import *
import urllib.parse

# %%
with open('../configs/bitrix24.yaml') as f:
    configs = yaml.safe_load(f)

portal = configs['portal']
apikey = configs['apikey']
uid = configs['uid']

# %% [markdown]
# ### Тестируем подключение к API

# %%
def get_xml(url):
    response = requests.get(url)
    return response.text

# %%
test_url = f'https://{portal}/rest/{uid}/{apikey}/profile/'
test_url
# Out:
# 'https://dilibrium.bitrix24.ru/rest/186/2nllymi3jljmwnwi/profile/'

# %%
js = get_xml('https://dilibrium.bitrix24.ru/rest/186/2nllymi3jljmwnwi/crm.deal.add')

# %%
json.loads(js)
# Out:
# {'result': 3548,
#  'time': {'start': 1590564109.014897,
#   'finish': 1590564109.279496,
#   'duration': 0.2645988464355469,
#   'processing': 0.23611187934875488,
#   'date_start': '2020-05-27T10:21:49+03:00',
#   'date_finish': '2020-05-27T10:21:49+03:00'}}

# %% [markdown]
# ### Формируем запрос к API

# %%
def http_build_query(query_data, 
                     numeric_prefix=None, 
                     arg_separator='&', 
                     enc_type='RFC1738') -> str:
    """Функция генерирует URL-кодированную строку запроса из предоставленного словаря или списка
    
    Аргументы:
    :params: query_data -- словарь или список, может быть как простой одномерной структурой, 
                           так и списком списков или словарем словарей
    :params: numeric_prefix -- числовые префиксы переменных
    :params: arg_separator -- используется в качестве разделителя аргументов, по умолчанию '&'
    :params: enc_type -- используется для кодирования контента,
                         по умолчанию используется кодирование по типу RFC1738, 
                         который подразумевает, что пробелы кодируются как символы "плюс"(+),
                         Если enc_type равен 'RFC3986', 
                         тогда кодирование осуществляется в соответствии RFC 3986, 
                         и пробелы будут кодированы как %20.
    :return: возвращает URL-кодированную строку
    """
    
    query = ''
    ENCODE = {'RFC1738': {'left_bracket': '%5B',
                          'right_bracket': '%5D',
                          'space': '+',
                         },
              'RFC3986': {'left_bracket': '%5B',
                          'right_bracket': '%5D',
                          'space': '%20',
                         },
             }
    
    def build_query_from_dict(qd=query_data, np=numeric_prefix, sep=arg_separator, et=enc_type):
        q = ''
        count = 0
        
        for key, value in qd.items():
            if not isinstance(value, (dict, list)):
                q += f"{key}={ENCODE[et]['space'].join(map(lambda s: urllib.parse.quote(s).replace('/', '%2F'), str(value).split()))}"
            elif isinstance(value, dict):
                
                    c = 0
                    for k, v in value.items():
                        if not isinstance(v, (dict, list)):
                            q += f"{key}{ENCODE[et]['left_bracket']}{k}{ENCODE[et]['right_bracket']}=" +\
                                 f"{ENCODE[et]['space'].join(map(lambda s: urllib.parse.quote(s).replace('/', '%2F'), str(v).split()))}"
                        
                        elif isinstance(v, list):
                            q += build_query_from_list(qd=v)
                        
                        elif isinstance(v, dict):
                            
                            _c = 0
                            for _k, _v in v.items():
                                q += f"{key}{ENCODE[et]['left_bracket']}{k}{ENCODE[et]['right_bracket']}" +\
                                     f"{ENCODE[et]['left_bracket']}{_k}{ENCODE[et]['right_bracket']}=" +\
                                     f"{ENCODE[et]['space'].join(map(lambda s: urllib.parse.quote(s).replace('/', '%2F'), str(_v).split()))}"
                                _c += 1

                                if _c < len(v):
                                    q += f"{sep}"
                                
                        c += 1

                        if c < len(value):
                            q += f"{sep}"
            

                        
            elif isinstance(value, list):
                
                    c = 0
                    for i, v in enumerate(value):
                        pr = i
                        if np is not None:
                            pr = f"{np}{i}"
                        
                        if not isinstance(v, (dict, list)):
                            q += f"{key}{ENCODE[et]['left_bracket']}{pr}{ENCODE[et]['right_bracket']}=" + \
                                 f"{ENCODE[et]['space'].join(map(lambda s: urllib.parse.quote(s).replace('/', '%2F'), str(v).split()))}"
                        
                        elif isinstance(v, list):
                            q += build_query_from_list(qd=v)
                        
                        elif isinstance(v, dict):
                            q += build_query_from_dict(qd=v)

                        c += 1

                        if c < len(value):
                            q += f"{sep}"
                

            count += 1
            if count < len(qd):
                q += f"{sep}"
    
        return q
    
    def build_query_from_list(qd=query_data, np=numeric_prefix, sep=arg_separator, et=enc_type):
        q = ''
        count = 0
        
        for i, value in enumerate(qd):
            pref = i
            if np is not None:
                pref = f"{np}{i}"
            
            if not isinstance(value, (dict, list)):
                q += f"{pref}={ENCODE[et]['space'].join(map(lambda s: urllib.parse.quote(s).replace('/', '%2F'), str(value).split()))}"
            elif isinstance(value, dict):
                q += build_query_from_dict(qd=value)
            elif isinstance(value, list):
                q += build_query_from_list(qd=value)
            
            count += 1
            if count < len(qd):
                q += f"{sep}"
    
        return q
    
    if isinstance(query_data, dict):
        query += build_query_from_dict()
    elif isinstance(query_data, list):
        query += build_query_from_list()
    
    return query

# %% [markdown]
#     TODO: оптимизировать функцию http_build_query(), сделать ее универсальной для производльного числав вложенных словарей (рекурсия-?)

# %% [markdown]
# ###### Тестирование запроса к API Битрикс24

# %%
api_method = 'crm.deal.add.json'

# %%
query_url = f'https://{portal}/rest/{uid}/{apikey}/{api_method}'
query_url
# Out:
# 'https://dilibrium.bitrix24.ru/rest/186/2nllymi3jljmwnwi/crm.deal.add.json'

# %%
def set_params(fields=dict(), params=dict(REGISTER_SONET_EVENT='Y')):
    _d = dict()
    _d = dict(fields=fields, params=params)
    return _d

# %%
qr = dict()

# %%
qr = set_params()

# %%
j = 16

# %%
j += 1
qr['fields']['TITLE'] = f'Тестовая сделка от тендербота № {j}'  #Название лида

# %% [markdown]
# Анна Пушкарева id = 414

# %%
qr['fields']['TYPE_ID'] = 107
qr['fields']['CATEGORY_ID'] = 8
qr['fields']['COMMENTS'] = 'Тестовая сделка по госзакупкам. Здесь будет текст комментария'
qr['fields']['OPENED'] = 'Y'
qr['fields']['ASSIGNED_BY_ID'] = 278
qr['fields']['UF_CRM_1548243578811'] = 250_000  # Обеспечение заявки
qr['fields']['UF_CRM_1548243648878'] = 37_500  # Обеспечение контракта
qr['fields']['OPPORTUNITY'] = 24_457_901  # Cтоимость контракта
# qr['fields']['ADDITIONAL_INFO'] = 'Здесь будет дополнительная информация о сделке'
qr['fields']['SOURCE_ID'] = 32

# %%
qr
# Out:
# {'fields': {'TITLE': 'Тестовая сделка от тендербота № 17',
#   'TYPE_ID': 107,
#   'CATEGORY_ID': 8,
#   'COMMENTS': 'Тестовая сделка по госзакупкам. Здесь будет текст комментария',
#   'OPENED': 'Y',
#   'ASSIGNED_BY_ID': 278,
#   'UF_CRM_1548243578811': 250000,
#   'UF_CRM_1548243648878': 37500,
#   'OPPORTUNITY': 24457901,
#   'SOURCE_ID': 32},
#  'params': {'REGISTER_SONET_EVENT': 'Y'}}

# %%
http_build_query(qr)
# Out:
# 'fields%5BTITLE%5D=%D0%A2%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%B0%D1%8F+%D1%81%D0%B4%D0%B5%D0%BB%D0%BA%D0%B0+%D0%BE%D1%82+%D1%82%D0%B5%D0%BD%D0%B4%D0%B5%D1%80%D0%B1%D0%BE%D1%82%D0%B0+%E2%84%96+17&fields%5BTYPE_ID%5D=107&fields%5BCATEGORY_ID%5D=8&fields%5BCOMMENTS%5D=%D0%A2%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%B0%D1%8F+%D1%81%D0%B4%D0%B5%D0%BB%D0%BA%D0%B0+%D0%BF%D0%BE+%D0%B3%D0%BE%D1%81%D0%B7%D0%B0%D0%BA%D1%83%D0%BF%D0%BA%D0%B0%D0%BC.+%D0%97%D0%B4%D0%B5%D1%81%D1%8C+%D0%B1%D1%83%D0%B4%D0%B5%D1%82+%D1%82%D0%B5%D0%BA%D1%81%D1%82+%D0%BA%D0%BE%D0%BC%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%80%D0%B8%D1%8F&fields%5BOPENED%5D=Y&fields%5BASSIGNED_BY_ID%5D=278&fields%5BUF_CRM_1548243578811%5D=250000&fields%5BUF_CRM_1548243648878%5D=37500&fields%5BOPPORTUNITY%5D=24457901&fields%5BSOURCE_ID%5D=32&params%5BREGISTER_SONET_EVENT%5D=Y'

# %%
def callMethod(url, api_method, params=None):
    query_url = f"{url}/{api_method}"
    if params:
        query_url += f"?{http_build_query(params)}" 
    response = requests.post(query_url)
    return response.text

# %%
uid = 278

# %%
callMethod(url=f'https://{portal}/rest/{uid}/{apikey}',
           api_method='crm.deal.add.json',
           params=qr,
          )
# Out:
# '{"result":3594,"time":{"start":1590584726.259418,"finish":1590584726.5547571,"duration":0.29533910751342773,"processing":0.26888799667358398,"date_start":"2020-05-27T16:05:26+03:00","date_finish":"2020-05-27T16:05:26+03:00"}}'

# %%
json.loads(callMethod(url=f'https://{portal}/rest/{uid}/{apikey}',
           api_method='crm.deal.fields',
          ))
# Out:
# {'result': {'ID': {'type': 'integer',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'ID'},
#   'TITLE': {'type': 'string',
#    'isRequired': True,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Название'},
#   'TYPE_ID': {'type': 'crm_status',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'statusType': 'DEAL_TYPE',
#    'title': 'Тип'},
#   'CATEGORY_ID': {'type': 'crm_category',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': True,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Направление'},
#   'STAGE_ID': {'type': 'crm_status',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'statusType': 'DEAL_STAGE',
#    'title': 'Стадия сделки'},
#   'STAGE_SEMANTIC_ID': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Группа стадии'},
#   'IS_NEW': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Новая сделка'},
#   'IS_RECURRING': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Регулярная сделка'},
#   'IS_RETURN_CUSTOMER': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Повторная сделка'},
#   'IS_REPEATED_APPROACH': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Повторное обращение'},
#   'PROBABILITY': {'type': 'integer',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Вероятность'},
#   'CURRENCY_ID': {'type': 'crm_currency',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Валюта'},
#   'OPPORTUNITY': {'type': 'double',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Сумма'},
#   'TAX_VALUE': {'type': 'double',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Ставка налога'},
#   'COMPANY_ID': {'type': 'crm_company',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Компания'},
#   'CONTACT_ID': {'type': 'crm_contact',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'isDeprecated': True,
#    'title': 'Контакт'},
#   'CONTACT_IDS': {'type': 'crm_contact',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': False,
#    'title': 'Контакты'},
#   'QUOTE_ID': {'type': 'crm_quote',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Предложение'},
#   'BEGINDATE': {'type': 'date',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дата начала'},
#   'CLOSEDATE': {'type': 'date',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дата завершения'},
#   'OPENED': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Доступна для всех'},
#   'CLOSED': {'type': 'char',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Закрыта'},
#   'COMMENTS': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Комментарий'},
#   'ASSIGNED_BY_ID': {'type': 'user',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Ответственный'},
#   'CREATED_BY_ID': {'type': 'user',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Кем создана'},
#   'MODIFY_BY_ID': {'type': 'user',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Кем изменена'},
#   'DATE_CREATE': {'type': 'datetime',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дата создания'},
#   'DATE_MODIFY': {'type': 'datetime',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дата изменения'},
#   'SOURCE_ID': {'type': 'crm_status',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'statusType': 'SOURCE',
#    'title': 'Источник'},
#   'SOURCE_DESCRIPTION': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дополнительно об источнике'},
#   'LEAD_ID': {'type': 'crm_lead',
#    'isRequired': False,
#    'isReadOnly': True,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Лид'},
#   'ADDITIONAL_INFO': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Дополнительная информация'},
#   'LOCATION_ID': {'type': 'location',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Местоположение'},
#   'ORIGINATOR_ID': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Внешний источник'},
#   'ORIGIN_ID': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Идентификатор элемента во внешнем источнике'},
#   'UTM_SOURCE': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Рекламная система'},
#   'UTM_MEDIUM': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Тип трафика'},
#   'UTM_CAMPAIGN': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Обозначение рекламной кампании'},
#   'UTM_CONTENT': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Содержание кампании'},
#   'UTM_TERM': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': False,
#    'title': 'Условие поиска кампании'},
#   'UF_CRM_59F1D464C7CB3': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_59F1D464C7CB3',
#    'listLabel': 'Номер документа',
#    'formLabel': 'Номер документа',
#    'filterLabel': 'Номер документа'},
#   'UF_CRM_B24_PORTAL': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_B24_PORTAL',
#    'listLabel': 'Адрес Б24 портала',
#    'formLabel': 'Адрес Б24 портала',
#    'filterLabel': 'UF_CRM_B24_PORTAL'},
#   'UF_CRM_LICENSE_KEY': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_LICENSE_KEY',
#    'listLabel': 'Лицензионный ключ',
#    'formLabel': 'Лицензионный ключ',
#    'filterLabel': 'UF_CRM_LICENSE_KEY'},
#   'UF_CRM_CITY': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_CITY',
#    'listLabel': 'Город',
#    'formLabel': 'Город',
#    'filterLabel': 'UF_CRM_CITY'},
#   'UF_CRM_1548243578811': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1548243578811',
#    'listLabel': 'Обеспечение заявки',
#    'formLabel': 'Обеспечение заявки',
#    'filterLabel': 'Обеспечение заявки'},
#   'UF_CRM_1548243648878': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1548243648878',
#    'listLabel': 'Обеспечение контракта',
#    'formLabel': 'Обеспечение контракта',
#    'filterLabel': 'Обеспечение контракта'},
#   'UF_CRM_1548243747417': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1548243747417',
#    'listLabel': 'Себестоимость контракта',
#    'formLabel': 'Себестоимость контракта',
#    'filterLabel': ''},
#   'UF_CRM_1548245317652': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1548245317652',
#    'listLabel': 'Расходы на подачу заявки специалистом',
#    'formLabel': 'Расходы на подачу заявки специалистом',
#    'filterLabel': 'Расходы на подачу заявки специалистом'},
#   'UF_CRM_1556281828109': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1556281828109',
#    'listLabel': 'Бриф',
#    'formLabel': 'Бриф',
#    'filterLabel': ''},
#   'UF_CRM_1558247110820': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1558247110820',
#    'listLabel': 'Олата проггеру',
#    'formLabel': 'Олата проггеру',
#    'filterLabel': 'Олата проггеру'},
#   'UF_CRM_1558247190043': {'type': 'boolean',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1558247190043',
#    'listLabel': 'Программист',
#    'formLabel': 'Программист',
#    'filterLabel': 'Программист'},
#   'UF_CRM_1558615548627': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'items': [{'ID': '44', 'VALUE': '100'}],
#    'title': 'UF_CRM_1558615548627',
#    'listLabel': 'Доб.номер',
#    'formLabel': 'Доб.номер',
#    'filterLabel': 'Доб.номер'},
#   'UF_CRM_5CEF978135C6C': {'type': 'address',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5CEF978135C6C',
#    'listLabel': 'Юридический адрес',
#    'formLabel': 'Юридический адрес',
#    'filterLabel': 'Юридический адрес'},
#   'UF_CRM_5CEF97814385E': {'type': 'double',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5CEF97814385E',
#    'listLabel': 'Количество сотрудников в компании:',
#    'formLabel': 'Количество сотрудников в компании:',
#    'filterLabel': 'Количество сотрудников в компании:'},
#   'UF_CRM_5CEF9781DCAF5': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5CEF9781DCAF5',
#    'listLabel': 'Другое',
#    'formLabel': 'Другое',
#    'filterLabel': 'Другое'},
#   'UF_CRM_5CEFE53DE1F61': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5CEFE53DE1F61',
#    'listLabel': 'Ссылка на Руспрофайл',
#    'formLabel': 'Ссылка на Руспрофайл',
#    'filterLabel': 'Ссылка на Руспрофайл'},
#   'UF_CRM_1565620402': {'type': 'date',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1565620402',
#    'listLabel': 'Срок исполнения договора',
#    'formLabel': 'Срок исполнения договора',
#    'filterLabel': 'Срок исполнения договора'},
#   'UF_CRM_1571661953581': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1571661953581',
#    'listLabel': 'КП',
#    'formLabel': 'КП',
#    'filterLabel': 'КП'},
#   'UF_CRM_1571661993505': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1571661993505',
#    'listLabel': 'Договор/доп. соглашение',
#    'formLabel': 'Договор/доп. соглашение',
#    'filterLabel': 'Договор/доп. соглашение'},
#   'UF_CRM_1571662053962': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1571662053962',
#    'listLabel': 'Акт выполненных работ',
#    'formLabel': 'Акт выполненных работ',
#    'filterLabel': 'Акт выполненных работ'},
#   'UF_CRM_1571662075744': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1571662075744',
#    'listLabel': 'Счет',
#    'formLabel': 'Счет',
#    'filterLabel': 'Счет'},
#   'UF_CRM_1571662415642': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1571662415642',
#    'listLabel': 'Заполненный клиентом бриф',
#    'formLabel': 'Заполненный клиентом бриф',
#    'filterLabel': 'Заполненный клиентом бриф'},
#   'UF_CRM_1573134809414': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1573134809414',
#    'listLabel': 'Особенности клиента',
#    'formLabel': 'Особенности клиента',
#    'filterLabel': 'Особенности клиента'},
#   'UF_CRM_1574341925589': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1574341925589',
#    'listLabel': 'Скан подписанного договора',
#    'formLabel': 'Скан подписанного договора',
#    'filterLabel': 'Скан подписанного договора'},
#   'UF_CRM_1574341973738': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1574341973738',
#    'listLabel': 'Квитанция об отправке СДЭК (договор)',
#    'formLabel': 'Квитанция об отправке СДЭК (договор)',
#    'filterLabel': 'Квитанция об отправке СДЭК (договор)'},
#   'UF_CRM_1574342000029': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1574342000029',
#    'listLabel': 'Квитанция об отправке СДЭК (Акт)',
#    'formLabel': 'Квитанция об отправке СДЭК (Акт)',
#    'filterLabel': 'Квитанция об отправке СДЭК (Акт)'},
#   'UF_CRM_1574342101566': {'type': 'url',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_1574342101566',
#    'listLabel': 'Ссылка на лк',
#    'formLabel': 'Ссылка на лк',
#    'filterLabel': 'Ссылка на лк'},
#   'UF_CRM_5E8D88F700CE3': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'items': [{'ID': '520', 'VALUE': 'менее 50'},
#     {'ID': '522', 'VALUE': '50-250'},
#     {'ID': '524', 'VALUE': '250-500'},
#     {'ID': '526', 'VALUE': 'более 500'}],
#    'title': 'UF_CRM_5E8D88F700CE3',
#    'listLabel': 'Кол-во сотрудников',
#    'formLabel': 'Кол-во сотрудников',
#    'filterLabel': 'Кол-во сотрудников'},
#   'UF_CRM_5E8D88F71CB18': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'items': [{'ID': '528',
#      'VALUE': 'Доклад по цифровой трансформации бизнеса'},
#     {'ID': '530',
#      'VALUE': 'Он-лайн консультация в области IT (15 - 30 минут)'},
#     {'ID': '532', 'VALUE': 'Письменный ответ на 1 вопрос по CRM Битрикс24'},
#     {'ID': '534', 'VALUE': 'Промокод для бесплатного тарифа Битрикс24'},
#     {'ID': '536',
#      'VALUE': 'Эксклюзивные условия для платного тарифа Битрикс24'},
#     {'ID': '538', 'VALUE': 'Приоритетная запись на внедрение Битрикс24'}],
#    'title': 'UF_CRM_5E8D88F71CB18',
#    'listLabel': 'Выберите бонусы, которые Вам интересны',
#    'formLabel': 'Выберите бонусы, которые Вам интересны',
#    'filterLabel': 'Выберите бонусы, которые Вам интересны'},
#   'UF_CRM_5E8D88F72E461': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'items': [{'ID': '540', 'VALUE': 'Информационные технологии'},
#     {'ID': '542', 'VALUE': 'Телекоммуникации и связь'},
#     {'ID': '544', 'VALUE': 'Производство'},
#     {'ID': '546', 'VALUE': 'Банковские услуги'},
#     {'ID': '548', 'VALUE': 'Консалтинг'},
#     {'ID': '550', 'VALUE': 'Финансы'},
#     {'ID': '552', 'VALUE': 'Правительство'},
#     {'ID': '554', 'VALUE': 'Доставка'},
#     {'ID': '556', 'VALUE': 'Развлечения'},
#     {'ID': '558', 'VALUE': 'Не для получения прибыли'},
#     {'ID': '560', 'VALUE': 'Другое'}],
#    'title': 'UF_CRM_5E8D88F72E461',
#    'listLabel': 'Сфера деятельности',
#    'formLabel': 'Сфера деятельности',
#    'filterLabel': 'Сфера деятельности'},
#   'UF_CRM_5E8D88F73E10D': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E8D88F73E10D',
#    'listLabel': 'Какой модуль сейчас проходите в АСБ?',
#    'formLabel': 'Какой модуль сейчас проходите в АСБ?',
#    'filterLabel': 'Какой модуль сейчас проходите в АСБ?'},
#   'UF_CRM_5E8D88F748F2A': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E8D88F748F2A',
#    'listLabel': 'Логин в телеграм чате АСБ',
#    'formLabel': 'Логин в телеграм чате АСБ',
#    'filterLabel': 'Логин в телеграм чате АСБ'},
#   'UF_CRM_5E8D88F757D96': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E8D88F757D96',
#    'listLabel': 'ИНН',
#    'formLabel': 'ИНН',
#    'filterLabel': 'ИНН'},
#   'UF_CRM_5E9F0B5172920': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'items': [{'ID': '796', 'VALUE': 'Да'},
#     {'ID': '798', 'VALUE': 'Нет'},
#     {'ID': '800', 'VALUE': 'Тестовая версия'}],
#    'title': 'UF_CRM_5E9F0B5172920',
#    'listLabel': 'Пользуетесь ли Вы системой Битрикс24?',
#    'formLabel': 'Пользуетесь ли Вы системой Битрикс24?',
#    'filterLabel': 'Пользуетесь ли Вы системой Битрикс24?'},
#   'UF_CRM_5E9F0B5184DCD': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E9F0B5184DCD',
#    'listLabel': 'Опишите цели, которые Вы ставите перед внедрение (например: автоматизация бизнеспроцессов, создание общего информационного пространства, увеличение производительности персонала, созание инструментов управления и анализа для руководителей (отчеты, контроль',
#    'formLabel': 'Опишите цели, которые Вы ставите перед внедрение (например: автоматизация бизнеспроцессов, создание общего информационного пространства, увеличение производительности персонала, созание инструментов управления и анализа для руководителей (отчеты, контроль',
#    'filterLabel': 'Опишите цели, которые Вы ставите перед внедрение (например: автоматизация бизнеспроцессов, создание общего информационного пространства, увеличение производительности персонала, созание инструментов управления и анализа для руководителей (отчеты, контроль'},
#   'UF_CRM_5E9F0B518DA58': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'items': [{'ID': '802', 'VALUE': '1С'},
#     {'ID': '804', 'VALUE': 'Мой склад'},
#     {'ID': '806', 'VALUE': 'Я.Касса'},
#     {'ID': '808', 'VALUE': 'IP-телефония'},
#     {'ID': '810', 'VALUE': 'Аналог.Телефония'},
#     {'ID': '812', 'VALUE': 'Соц.сети'},
#     {'ID': '814', 'VALUE': 'Сайт'},
#     {'ID': '816', 'VALUE': 'R-keeper'}],
#    'title': 'UF_CRM_5E9F0B518DA58',
#    'listLabel': 'Перечислите системы автоматизации и коммуникации, которые сейчас используются в компании (например:1С, МС, Я.Касса, телефония, соц.сети и т.д).',
#    'formLabel': 'Перечислите системы автоматизации и коммуникации, которые сейчас используются в компании (например:1С, МС, Я.Касса, телефония, соц.сети и т.д).',
#    'filterLabel': 'Перечислите системы автоматизации и коммуникации, которые сейчас используются в компании (например:1С, МС, Я.Касса, телефония, соц.сети и т.д).'},
#   'UF_CRM_5E9F0B519AC3E': {'type': 'money',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E9F0B519AC3E',
#    'listLabel': 'Укажите планируемый бюджет данного проекта',
#    'formLabel': 'Укажите планируемый бюджет данного проекта',
#    'filterLabel': 'Укажите планируемый бюджет данного проекта'},
#   'UF_CRM_5E9F0B51A21D1': {'type': 'enumeration',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'items': [{'ID': '818', 'VALUE': 'Цена'},
#     {'ID': '820', 'VALUE': 'Срок выполнения'},
#     {'ID': '822', 'VALUE': 'Компетенция подрядчика'},
#     {'ID': '824', 'VALUE': 'Индивидуальный подход'},
#     {'ID': '826', 'VALUE': 'Другое'}],
#    'title': 'UF_CRM_5E9F0B51A21D1',
#    'listLabel': 'Что для Вас наиболее важно, при выборе подрядчика по внедрению CRM-системы?',
#    'formLabel': 'Что для Вас наиболее важно, при выборе подрядчика по внедрению CRM-системы?',
#    'filterLabel': 'Что для Вас наиболее важно, при выборе подрядчика по внедрению CRM-системы?'},
#   'UF_CRM_5E9F0B51AF72C': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_5E9F0B51AF72C',
#    'listLabel': 'Комментарии, пожелания, мысли и идеи. Если Вы считаете, что мы что-то не учли или у Вас есть конкретные пожелания, просим изложить их в данном пункте',
#    'formLabel': 'Комментарии, пожелания, мысли и идеи. Если Вы считаете, что мы что-то не учли или у Вас есть конкретные пожелания, просим изложить их в данном пункте',
#    'filterLabel': 'Комментарии, пожелания, мысли и идеи. Если Вы считаете, что мы что-то не учли или у Вас есть конкретные пожелания, просим изложить их в данном пункте'},
#   'UF_CRM_PHOTOS': {'type': 'file',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'title': 'UF_CRM_PHOTOS',
#    'listLabel': 'Фото-файлы',
#    'formLabel': 'Фото-файлы',
#    'filterLabel': 'UF_CRM_PHOTOS'},
#   'UF_CRM_COMMENTS': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'title': 'UF_CRM_COMMENTS',
#    'listLabel': 'Комментарии',
#    'formLabel': 'Комментарии',
#    'filterLabel': 'UF_CRM_COMMENTS'},
#   'UF_CRM_GEOMARK': {'type': 'address',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': True,
#    'isDynamic': True,
#    'title': 'UF_CRM_GEOMARK',
#    'listLabel': 'Геометка',
#    'formLabel': 'Геометка',
#    'filterLabel': 'UF_CRM_GEOMARK'},
#   'UF_CRM_PHOTOREPORT': {'type': 'string',
#    'isRequired': False,
#    'isReadOnly': False,
#    'isImmutable': False,
#    'isMultiple': False,
#    'isDynamic': True,
#    'title': 'UF_CRM_PHOTOREPORT',
#    'listLabel': 'Признак фотоотчет',
#    'formLabel': 'Признак фотоотчет',
#    'filterLabel': 'UF_CRM_PHOTOREPORT'}},
#  'time': {'start': 1590584954.011749,
#   'finish': 1590584954.046741,
#   'duration': 0.03499197959899902,
#   'processing': 0.007487058639526367,
#   'date_start': '2020-05-27T16:09:14+03:00',
#   'date_finish': '2020-05-27T16:09:14+03:00'}}

# %%
json.loads(callMethod(url=f'https://{portal}/rest/{uid}/{apikey}',
           api_method='crm.status.list',
          ))
# Out:
# {'result': [{'ID': '1',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': 'NEW',
#    'NAME': 'Не обработан',
#    'NAME_INIT': 'Не обработан',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#aae9fc'}},
#   {'ID': '19',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'SELF',
#    'NAME': 'Свой контакт',
#    'NAME_INIT': 'Свой контакт',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '71',
#    'ENTITY_ID': 'EMPLOYEES',
#    'STATUS_ID': 'EMPLOYEES_1',
#    'NAME': 'менее 50',
#    'NAME_INIT': 'менее 50',
#    'SORT': '10',
#    'SYSTEM': 'Y'},
#   {'ID': '83',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'MANUFACTURING',
#    'NAME': 'Производство',
#    'NAME_INIT': '',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '101',
#    'ENTITY_ID': 'DEAL_TYPE',
#    'STATUS_ID': 'SALE',
#    'NAME': 'Продажа',
#    'NAME_INIT': 'Продажа',
#    'SORT': '10',
#    'SYSTEM': 'Y'},
#   {'ID': '111',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'NEW',
#    'NAME': 'Новая',
#    'NAME_INIT': 'В обработке',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '125',
#    'ENTITY_ID': 'DEAL_STATE',
#    'STATUS_ID': 'PLANNED',
#    'NAME': 'В планах',
#    'NAME_INIT': '',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '133',
#    'ENTITY_ID': 'EVENT_TYPE',
#    'STATUS_ID': 'INFO',
#    'NAME': 'Информация',
#    'NAME_INIT': 'Информация',
#    'SORT': '10',
#    'SYSTEM': 'Y'},
#   {'ID': '139',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'DRAFT',
#    'NAME': 'Черновик',
#    'NAME_INIT': 'Черновик',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '151',
#    'ENTITY_ID': 'HONORIFIC',
#    'STATUS_ID': 'HNR_RU_1',
#    'NAME': 'г-н',
#    'NAME_INIT': '',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '162',
#    'ENTITY_ID': 'CALL_LIST',
#    'STATUS_ID': 'IN_WORK',
#    'NAME': 'В работе',
#    'NAME_INIT': 'В работе',
#    'SORT': '10',
#    'SYSTEM': 'Y'},
#   {'ID': '196',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:NEW',
#    'NAME': 'Новая',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '214',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:NEW',
#    'NAME': 'Новая',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#652C91'}},
#   {'ID': '230',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': '1',
#    'NAME': 'Клиент - вип',
#    'NAME_INIT': '',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '236',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:NEW',
#    'NAME': 'Контакт создан',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '290',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:NEW',
#    'NAME': 'Новый тендер',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#DBDDE0'}},
#   {'ID': '318',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '12',
#    'NAME': 'Общий',
#    'NAME_INIT': '',
#    'SORT': '10',
#    'SYSTEM': 'N'},
#   {'ID': '342',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:NEW',
#    'NAME': 'Переговоры с заказчиком',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '363',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:NEW',
#    'NAME': 'Новая сделка',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39a8ef'}},
#   {'ID': '436',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:NEW',
#    'NAME': 'Новая',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '516',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:NEW',
#    'NAME': 'Новая',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '560',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:NEW',
#    'NAME': 'Новая регистрация',
#    'NAME_INIT': 'Новая',
#    'SORT': '10',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '9',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': 'IN_PROCESS',
#    'NAME': 'В обработке',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '21',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'PARTNER',
#    'NAME': 'Существующий клиент',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '73',
#    'ENTITY_ID': 'EMPLOYEES',
#    'STATUS_ID': 'EMPLOYEES_2',
#    'NAME': '50-250',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '103',
#    'ENTITY_ID': 'DEAL_TYPE',
#    'STATUS_ID': 'COMPLEX',
#    'NAME': 'Комплексная продажа',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '113',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'DETAILS',
#    'NAME': 'Первое письмо',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '127',
#    'ENTITY_ID': 'DEAL_STATE',
#    'STATUS_ID': 'PROCESS',
#    'NAME': 'В работе',
#    'NAME_INIT': 'В работе',
#    'SORT': '20',
#    'SYSTEM': 'Y'},
#   {'ID': '135',
#    'ENTITY_ID': 'EVENT_TYPE',
#    'STATUS_ID': 'PHONE',
#    'NAME': 'Телефонный звонок',
#    'NAME_INIT': 'Телефонный звонок',
#    'SORT': '20',
#    'SYSTEM': 'Y'},
#   {'ID': '141',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'SENT',
#    'NAME': 'Отправлено клиенту',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '153',
#    'ENTITY_ID': 'HONORIFIC',
#    'STATUS_ID': 'HNR_RU_2',
#    'NAME': 'г-жа',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '164',
#    'ENTITY_ID': 'CALL_LIST',
#    'STATUS_ID': 'SUCCESS',
#    'NAME': 'Успешно',
#    'NAME_INIT': 'Успешно',
#    'SORT': '20',
#    'SYSTEM': 'Y'},
#   {'ID': '232',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': '2',
#    'NAME': 'Клиент - теплый',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '240',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:PREPAYMENT_INVOICE',
#    'NAME': 'Звонок сделан',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '268',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '1',
#    'NAME': 'Клиент ВИП',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '328',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:1',
#    'NAME': 'Отправлен Бриф',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#ACE9FB'}},
#   {'ID': '358',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:1',
#    'NAME': 'Согласование плана работ',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '379',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:1',
#    'NAME': 'Презентация отправлена',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39a8ef'}},
#   {'ID': '452',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:1',
#    'NAME': 'Первое письмо',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '494',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:1',
#    'NAME': 'Обсуждение задачи',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#91278F'}},
#   {'ID': '518',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:PREPARATION',
#    'NAME': 'Выбор тарифа',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '552',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:10',
#    'NAME': 'Первичный анализ',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#D7D7D7'}},
#   {'ID': '556',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': '1',
#    'NAME': 'Ритейл',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N'},
#   {'ID': '562',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:PREPARATION',
#    'NAME': 'Отправка напоминания за 3дня',
#    'NAME_INIT': '',
#    'SORT': '20',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2fc6f6'}},
#   {'ID': '15',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': 'CONVERTED',
#    'NAME': 'Сконвертирован',
#    'NAME_INIT': 'Сконвертирован',
#    'SORT': '30',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '23',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'CALL',
#    'NAME': 'Звонок',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'Y'},
#   {'ID': '75',
#    'ENTITY_ID': 'EMPLOYEES',
#    'STATUS_ID': 'EMPLOYEES_3',
#    'NAME': '250-500',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N'},
#   {'ID': '93',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'DELIVERY',
#    'NAME': 'Логистические услуги',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N'},
#   {'ID': '105',
#    'ENTITY_ID': 'DEAL_TYPE',
#    'STATUS_ID': 'GOODS',
#    'NAME': 'Продажа товара',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N'},
#   {'ID': '115',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'PROPOSAL',
#    'NAME': 'Получен ответ',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '129',
#    'ENTITY_ID': 'DEAL_STATE',
#    'STATUS_ID': 'COMPLETE',
#    'NAME': 'Выполнена',
#    'NAME_INIT': 'Выполнена',
#    'SORT': '30',
#    'SYSTEM': 'Y'},
#   {'ID': '137',
#    'ENTITY_ID': 'EVENT_TYPE',
#    'STATUS_ID': 'MESSAGE',
#    'NAME': 'Отправлен email',
#    'NAME_INIT': 'Отправлен email',
#    'SORT': '30',
#    'SYSTEM': 'Y'},
#   {'ID': '143',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'RECEIVED',
#    'NAME': 'Рассматривается клиентом',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '166',
#    'ENTITY_ID': 'CALL_LIST',
#    'STATUS_ID': 'WRONG_NUMBER',
#    'NAME': 'Неверный номер',
#    'NAME_INIT': 'Неверный номер',
#    'SORT': '30',
#    'SYSTEM': 'Y'},
#   {'ID': '234',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': '3',
#    'NAME': 'Клиент - холодный',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N'},
#   {'ID': '238',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:PREPARATION',
#    'NAME': 'Предложение отправлено',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '270',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '2',
#    'NAME': 'Клиент теплый',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N'},
#   {'ID': '330',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:2',
#    'NAME': 'Получен Бриф - подготовка КП',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#BEEDF1'}},
#   {'ID': '362',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:3',
#    'NAME': 'Коммерческое предложение отправлено',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '381',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:2',
#    'NAME': 'Презентация получена',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2fc6f6'}},
#   {'ID': '454',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:2',
#    'NAME': 'Отправлен Бриф',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '506',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:4',
#    'NAME': 'КП отправлено',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#A763A9'}},
#   {'ID': '520',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:PREPAYMENT_INVOICE',
#    'NAME': 'Cчёт',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '554',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:11',
#    'NAME': 'Анализ на скрытые ограничения',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '564',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:PREPAYMENT_INVOICE',
#    'NAME': 'Отправка напоминания за сутки',
#    'NAME_INIT': '',
#    'SORT': '30',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55d0e0'}},
#   {'ID': '17',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': 'JUNK',
#    'NAME': 'Спам',
#    'NAME_INIT': 'Некачественный лид',
#    'SORT': '40',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '25',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'WEB',
#    'NAME': 'Веб-сайт',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '53',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'CUSTOMER',
#    'NAME': 'Клиент',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '77',
#    'ENTITY_ID': 'EMPLOYEES',
#    'STATUS_ID': 'EMPLOYEES_4',
#    'NAME': 'более 500',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '79',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'IT',
#    'NAME': 'Информационные технологии',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '107',
#    'ENTITY_ID': 'DEAL_TYPE',
#    'STATUS_ID': 'SERVICES',
#    'NAME': 'Продажа услуги',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '117',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'NEGOTIATION',
#    'NAME': 'Изучение клиента',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47E4C2'}},
#   {'ID': '131',
#    'ENTITY_ID': 'DEAL_STATE',
#    'STATUS_ID': 'CANCELED',
#    'NAME': 'Отменена',
#    'NAME_INIT': 'Отменена',
#    'SORT': '40',
#    'SYSTEM': 'Y'},
#   {'ID': '145',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'APPROVED',
#    'NAME': 'Утверждено',
#    'NAME_INIT': 'Утверждено',
#    'SORT': '40',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '168',
#    'ENTITY_ID': 'CALL_LIST',
#    'STATUS_ID': 'STOP_CALLING',
#    'NAME': 'Больше не звонить',
#    'NAME_INIT': 'Больше не звонить',
#    'SORT': '40',
#    'SYSTEM': 'Y'},
#   {'ID': '216',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:PREPARATION',
#    'NAME': 'Договор согласован',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#BC8CBF'}},
#   {'ID': '242',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:EXECUTING',
#    'NAME': 'Информация уточнена',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '272',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '3',
#    'NAME': 'Клиент холодный',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N'},
#   {'ID': '292',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:PREPARATION',
#    'NAME': 'Подготовка документов',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '332',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:3',
#    'NAME': 'КП отправлено',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#9AE1DD'}},
#   {'ID': '344',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:PREPARATION',
#    'NAME': 'Подготовка договора',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '385',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:4',
#    'NAME': 'КП отправлено - обсуждение',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '456',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:3',
#    'NAME': 'Получен Бриф - подготовка КП',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '522',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:EXECUTING',
#    'NAME': 'Партнерский кабинет Б24',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47E4C2'}},
#   {'ID': '568',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:FINAL_INVOICE',
#    'NAME': 'Отправка за час напоминания и ссылки трансляции',
#    'NAME_INIT': '',
#    'SORT': '40',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#ffa900'}},
#   {'ID': '55',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'PARTNER',
#    'NAME': 'Партнер',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N'},
#   {'ID': '81',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'TELECOM',
#    'NAME': 'Телекоммуникации и связь',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N'},
#   {'ID': '109',
#    'ENTITY_ID': 'DEAL_TYPE',
#    'STATUS_ID': 'SERVICE',
#    'NAME': 'Сервисное обслуживание',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N'},
#   {'ID': '154',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'ADVERTISING',
#    'NAME': 'Реклама',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N'},
#   {'ID': '198',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:PREPARATION',
#    'NAME': 'Договор согласован',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#E3F19E'}},
#   {'ID': '218',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:PREPAYMENT_INVOICE',
#    'NAME': 'Счет отправлен',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2F3192'}},
#   {'ID': '244',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:FINAL_INVOICE',
#    'NAME': 'Встреча назначена',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '280',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '7',
#    'NAME': 'Pre-Sale',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N'},
#   {'ID': '294',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:PREPAYMENT_INVOICE',
#    'NAME': 'Документы поданы',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '324',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': '1',
#    'NAME': 'Неверные контакты',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '383',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:3',
#    'NAME': 'Расчет сметы',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39a8ef'}},
#   {'ID': '458',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:4',
#    'NAME': 'КП отправлено',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47E4C2'}},
#   {'ID': '486',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': '1',
#    'NAME': 'Внутреннее принятие решения о сотрудничестве',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '524',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:FINAL_INVOICE',
#    'NAME': 'Оплата партнерского счета',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '538',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:4',
#    'NAME': 'Договор заключен',
#    'NAME_INIT': '',
#    'SORT': '50',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '570',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '50',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '27',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'EMAIL',
#    'NAME': 'Электронная почта',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N'},
#   {'ID': '51',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': 'PARTNER',
#    'NAME': 'Партнеры',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N'},
#   {'ID': '59',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'COMPETITOR',
#    'NAME': 'Конкурент',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N'},
#   {'ID': '85',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'BANKING',
#    'NAME': 'Банковские услуги',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N'},
#   {'ID': '149',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'DECLAINED',
#    'NAME': 'Отклонено',
#    'NAME_INIT': 'Отклонено',
#    'SORT': '60',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '252',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:1',
#    'NAME': 'Переговоры проведены',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '326',
#    'ENTITY_ID': 'STATUS',
#    'STATUS_ID': '2',
#    'NAME': 'Возможный конкурент',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '346',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:PREPAYMENT_INVOICE',
#    'NAME': 'Cчёт на предоплату выставлен',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '406',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:1',
#    'NAME': 'Проведение торгов',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '420',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:8',
#    'NAME': 'Сбор съемочной группы',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47d1e2'}},
#   {'ID': '460',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:5',
#    'NAME': 'Подготовка договора и счета на предоплату',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '488',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': '2',
#    'NAME': 'Звонок клиенту',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '500',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:11',
#    'NAME': 'Выставление счета',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '508',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:5',
#    'NAME': 'Отправка договора (сдэк)',
#    'NAME_INIT': '',
#    'SORT': '60',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#5E5CA7'}},
#   {'ID': '526',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '60',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '572',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '60',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '61',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'INVESTOR',
#    'NAME': 'Инвестор',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N'},
#   {'ID': '147',
#    'ENTITY_ID': 'QUOTE_STATUS',
#    'STATUS_ID': 'UNANSWERED',
#    'NAME': 'Ответ не получен',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '156',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'RECOMMENDATION',
#    'NAME': 'По рекомендации',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N'},
#   {'ID': '200',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:PREPAYMENT_INVOICE',
#    'NAME': 'Отправка договора (сдэк)',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFED9A'}},
#   {'ID': '254',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:2',
#    'NAME': 'Договор разработан',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '282',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '8',
#    'NAME': 'Конкуренты',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N'},
#   {'ID': '365',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:PREPARATION',
#    'NAME': 'Подготовка договора с предоплатой',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '462',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:6',
#    'NAME': 'Договор и счет отправлены',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '478',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:4',
#    'NAME': 'Заключение контракта',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '490',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': '3',
#    'NAME': 'Актуализация потребности',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '510',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:6',
#    'NAME': 'Договор получен',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#5573B7'}},
#   {'ID': '528',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '70',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '540',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:5',
#    'NAME': 'Счет на предоплату оплачен',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '558',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': '2',
#    'NAME': 'Кафе и рестраны',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N'},
#   {'ID': '574',
#    'ENTITY_ID': 'DEAL_STAGE_18',
#    'STATUS_ID': 'C18:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '70',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '49',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': 'SUPPLIER',
#    'NAME': 'Поставщики',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N'},
#   {'ID': '63',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'INTEGRATOR',
#    'NAME': 'Интегратор',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N'},
#   {'ID': '87',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'CONSULTING',
#    'NAME': 'Консалтинг',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N'},
#   {'ID': '119',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'WON',
#    'NAME': 'Сделка заключена',
#    'NAME_INIT': 'Сделка заключена',
#    'SORT': '80',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '158',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'WEBFORM',
#    'NAME': 'CRM-форма',
#    'NAME_INIT': 'CRM-форма',
#    'SORT': '80',
#    'SYSTEM': 'Y'},
#   {'ID': '256',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:3',
#    'NAME': 'Договор согласован',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '348',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:EXECUTING',
#    'NAME': 'Исполнение договора',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA801'}},
#   {'ID': '367',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:PREPAYMENT_INVOICE',
#    'NAME': 'Договор и счет на предоплату отправлены',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '464',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:7',
#    'NAME': 'Поступила предоплата по договору',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#2FC6F6'}},
#   {'ID': '480',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:5',
#    'NAME': 'Контракт заключен',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '492',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:10',
#    'NAME': 'Договор получен',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '512',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:7',
#    'NAME': 'Оплата получена',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#0072BC'}},
#   {'ID': '530',
#    'ENTITY_ID': 'DEAL_STAGE_16',
#    'STATUS_ID': 'C16:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '80',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '67',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'PRESS',
#    'NAME': 'СМИ',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N'},
#   {'ID': '89',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'FINANCE',
#    'NAME': 'Финансы',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N'},
#   {'ID': '123',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'LOSE',
#    'NAME': 'Сделка не заключена',
#    'NAME_INIT': 'Сделка не заключена',
#    'SORT': '90',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '220',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:EXECUTING',
#    'NAME': 'В работе',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#438CCB'}},
#   {'ID': '258',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:4',
#    'NAME': 'Договор подписан',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFF100'}},
#   {'ID': '276',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '5',
#    'NAME': 'Архив',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N'},
#   {'ID': '360',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:2',
#    'NAME': 'Акт(-ы) выполненных работ подписан(-ы)',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '387',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:5',
#    'NAME': 'Поступление предоплаты',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '426',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '30|OPENLINE',
#    'NAME': 'Онлайн-чат - Открытая линия Media',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N'},
#   {'ID': '466',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:8',
#    'NAME': 'В работе',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#55D0E0'}},
#   {'ID': '482',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:6',
#    'NAME': 'Исполнение контракта',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA801'}},
#   {'ID': '502',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:12',
#    'NAME': 'Получена предоплата',
#    'NAME_INIT': '',
#    'SORT': '90',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '69',
#    'ENTITY_ID': 'COMPANY_TYPE',
#    'STATUS_ID': 'OTHER',
#    'NAME': 'Другое',
#    'NAME_INIT': 'Другое',
#    'SORT': '100',
#    'SYSTEM': 'N'},
#   {'ID': '95',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'ENTERTAINMENT',
#    'NAME': 'Развлечения',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N'},
#   {'ID': '121',
#    'ENTITY_ID': 'DEAL_STAGE',
#    'STATUS_ID': 'ON_HOLD',
#    'NAME': 'Обработка приостановлена',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '170',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'CALLBACK',
#    'NAME': 'Обратный звонок',
#    'NAME_INIT': 'Обратный звонок',
#    'SORT': '100',
#    'SYSTEM': 'Y'},
#   {'ID': '184',
#    'ENTITY_ID': 'INVOICE_STATUS',
#    'STATUS_ID': 'N',
#    'NAME': 'Черновик',
#    'NAME_INIT': 'Черновик',
#    'SORT': '100',
#    'SYSTEM': 'Y'},
#   {'ID': '262',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:6',
#    'NAME': 'Исполнение договора',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA801'}},
#   {'ID': '278',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '6',
#    'NAME': 'Мошенники',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N'},
#   {'ID': '334',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:4',
#    'NAME': 'В работе',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFDD99'}},
#   {'ID': '350',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:FINAL_INVOICE',
#    'NAME': 'Счет по договору выставлен',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '369',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:EXECUTING',
#    'NAME': 'Съемочный период',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47e4c2'}},
#   {'ID': '468',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:9',
#    'NAME': 'Финальный счет',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#47E4C2'}},
#   {'ID': '514',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:8',
#    'NAME': 'Формирование акта',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#7CA6D8'}},
#   {'ID': '532',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:8',
#    'NAME': 'Акт(-ы) выполненных работы подписан(-ы)',
#    'NAME_INIT': '',
#    'SORT': '100',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '45',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': 'JOURNALIST',
#    'NAME': 'Журналисты',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N'},
#   {'ID': '99',
#    'ENTITY_ID': 'INDUSTRY',
#    'STATUS_ID': 'OTHER',
#    'NAME': 'Другое',
#    'NAME_INIT': 'Другое',
#    'SORT': '110',
#    'SYSTEM': 'Y'},
#   {'ID': '178',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'RC_GENERATOR',
#    'NAME': 'Конференция',
#    'NAME_INIT': 'Генератор продаж',
#    'SORT': '110',
#    'SYSTEM': 'Y'},
#   {'ID': '188',
#    'ENTITY_ID': 'INVOICE_STATUS',
#    'STATUS_ID': 'S',
#    'NAME': 'Отправлен клиенту',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N'},
#   {'ID': '266',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:8',
#    'NAME': 'Акт(-ы) выполненных работ подписан(-ы)',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '422',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:9',
#    'NAME': 'Монтажно-тонировочный период',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#75d900'}},
#   {'ID': '470',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:10',
#    'NAME': 'Подготовка и отправка акта о выполненных работах',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '496',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:2',
#    'NAME': 'Акт отправлен (сдэк)',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00AEEF'}},
#   {'ID': '504',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:13',
#    'NAME': 'Формирование акта',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '534',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:9',
#    'NAME': 'Счет на оплату выставлен',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '542',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:6',
#    'NAME': 'Оплата по договору поступила',
#    'NAME_INIT': '',
#    'SORT': '110',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '180',
#    'ENTITY_ID': 'INVOICE_STATUS',
#    'STATUS_ID': 'A',
#    'NAME': 'Подтверждён',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N'},
#   {'ID': '202',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:EXECUTING',
#    'NAME': 'Акт отправлен (сдэк)',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#DFD3B7'}},
#   {'ID': '284',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '9',
#    'NAME': 'Наша команда',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N'},
#   {'ID': '428',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:10',
#    'NAME': 'Показ проекта',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00bdb5'}},
#   {'ID': '472',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:11',
#    'NAME': 'Акт о выполненных работах подписан и получен',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#39A8EF'}},
#   {'ID': '484',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:7',
#    'NAME': 'Оплата по договору поступила',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '498',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:3',
#    'NAME': 'Акт подписан и получен',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#16BCB4'}},
#   {'ID': '544',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:7',
#    'NAME': 'Исполнение гарантийных обязательств',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#A763A9'}},
#   {'ID': '546',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:9',
#    'NAME': 'Счет на оплату выставлен',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '576',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '2|TELEGRAM',
#    'NAME': 'Telegram - Открытая линия Dilibrium',
#    'NAME_INIT': '',
#    'SORT': '120',
#    'SYSTEM': 'N'},
#   {'ID': '186',
#    'ENTITY_ID': 'INVOICE_STATUS',
#    'STATUS_ID': 'P',
#    'NAME': 'Оплачен',
#    'NAME_INIT': 'Оплачен',
#    'SORT': '130',
#    'SYSTEM': 'Y'},
#   {'ID': '224',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '130',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '260',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:5',
#    'NAME': 'Оплата по договору поступила',
#    'NAME_INIT': '',
#    'SORT': '130',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#00A650'}},
#   {'ID': '286',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '10',
#    'NAME': 'Эксперты и визионеры',
#    'NAME_INIT': '',
#    'SORT': '130',
#    'SYSTEM': 'N'},
#   {'ID': '300',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:WON',
#    'NAME': 'Контракт исполнен',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '130',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#00A650'}},
#   {'ID': '352',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:WON',
#    'NAME': 'Договор исполнен',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '130',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#00A650'}},
#   {'ID': '371',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:FINAL_INVOICE',
#    'NAME': 'Финальный счёт',
#    'NAME_INIT': '',
#    'SORT': '130',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#FFA900'}},
#   {'ID': '432',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:8',
#    'NAME': 'Акт подписан и получен',
#    'NAME_INIT': '',
#    'SORT': '130',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#43DAD2'}},
#   {'ID': '446',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '130',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '578',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '2|YANDEX',
#    'NAME': 'Яндекс чат - Открытая линия Dilibrium',
#    'NAME_INIT': '',
#    'SORT': '130',
#    'SYSTEM': 'N'},
#   {'ID': '182',
#    'ENTITY_ID': 'INVOICE_STATUS',
#    'STATUS_ID': 'D',
#    'NAME': 'Отклонён',
#    'NAME_INIT': 'Отклонён',
#    'SORT': '140',
#    'SYSTEM': 'Y'},
#   {'ID': '206',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '226',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '246',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:WON',
#    'NAME': 'Договор исполнен',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#00A650'}},
#   {'ID': '288',
#    'ENTITY_ID': 'CONTACT_TYPE',
#    'STATUS_ID': '11',
#    'NAME': 'Островитяне',
#    'NAME_INIT': '',
#    'SORT': '140',
#    'SYSTEM': 'N'},
#   {'ID': '302',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:LOSE',
#    'NAME': 'Проигрыш',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#9D0A0F'}},
#   {'ID': '354',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#9D0A0F'}},
#   {'ID': '404',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:6',
#    'NAME': 'Реализация проекта',
#    'NAME_INIT': '',
#    'SORT': '140',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'process', 'COLOR': '#7bc56f'}},
#   {'ID': '448',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '140',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '548',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '2|FACEBOOK',
#    'NAME': 'Facebook - Открытая линия Dilibrium',
#    'NAME_INIT': '',
#    'SORT': '140',
#    'SYSTEM': 'N'},
#   {'ID': '194',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'STORE',
#    'NAME': 'Партнерка Б24',
#    'NAME_INIT': 'Интернет-магазин',
#    'SORT': '150',
#    'SYSTEM': 'Y'},
#   {'ID': '208',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '150',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '228',
#    'ENTITY_ID': 'DEAL_STAGE_4',
#    'STATUS_ID': 'C4:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '150',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '248',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '150',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#9D0A0F'}},
#   {'ID': '356',
#    'ENTITY_ID': 'DEAL_STAGE_10',
#    'STATUS_ID': 'C10:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '150',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#9D0A0F'}},
#   {'ID': '373',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:WON',
#    'NAME': 'Сделка успешна',
#    'NAME_INIT': 'Сделка успешна',
#    'SORT': '150',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'success', 'COLOR': '#7BD500'}},
#   {'ID': '408',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:2',
#    'NAME': 'Отказ от участия',
#    'NAME_INIT': '',
#    'SORT': '150',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#9D0A0F'}},
#   {'ID': '450',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:APOLOGY',
#    'NAME': 'Не удалось согласовать стоимость',
#    'NAME_INIT': '',
#    'SORT': '150',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '33',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'EMPLOYEE',
#    'NAME': 'Сотрудник',
#    'NAME_INIT': '',
#    'SORT': '160',
#    'SYSTEM': 'N'},
#   {'ID': '210',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:APOLOGY',
#    'NAME': 'Не удалось согласовать стоимость услуги',
#    'NAME_INIT': '',
#    'SORT': '160',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '250',
#    'ENTITY_ID': 'DEAL_STAGE_6',
#    'STATUS_ID': 'C6:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '160',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#9D0A0F'}},
#   {'ID': '375',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:LOSE',
#    'NAME': 'Сделка провалена',
#    'NAME_INIT': 'Сделка провалена',
#    'SORT': '160',
#    'SYSTEM': 'Y',
#    'EXTRA': {'SEMANTICS': 'failure', 'COLOR': '#FF5752'}},
#   {'ID': '410',
#    'ENTITY_ID': 'DEAL_STAGE_8',
#    'STATUS_ID': 'C8:3',
#    'NAME': 'Жалоба в ФАС',
#    'NAME_INIT': '',
#    'SORT': '160',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#9D0A0F'}},
#   {'ID': '474',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:12',
#    'NAME': 'Не удалось согласовать сроки реализации',
#    'NAME_INIT': '',
#    'SORT': '160',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '35',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'COMPANY',
#    'NAME': 'Кампания',
#    'NAME_INIT': '',
#    'SORT': '170',
#    'SYSTEM': 'N'},
#   {'ID': '336',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:5',
#    'NAME': 'Не удалось согласовать срок реализации',
#    'NAME_INIT': '',
#    'SORT': '170',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '377',
#    'ENTITY_ID': 'DEAL_STAGE_11',
#    'STATUS_ID': 'C11:APOLOGY',
#    'NAME': 'Анализ причины провала',
#    'NAME_INIT': '',
#    'SORT': '170',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '476',
#    'ENTITY_ID': 'DEAL_STAGE_14',
#    'STATUS_ID': 'C14:13',
#    'NAME': 'Клиент отложил внедрение',
#    'NAME_INIT': '',
#    'SORT': '170',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '160',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '2|VK',
#    'NAME': 'ВКонтакте - Открытая линия Dilibrium',
#    'NAME_INIT': '',
#    'SORT': '180',
#    'SYSTEM': 'N'},
#   {'ID': '338',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:6',
#    'NAME': 'Клиент отложил внедрение',
#    'NAME_INIT': '',
#    'SORT': '180',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '41',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'OTHER',
#    'NAME': 'Другое',
#    'NAME_INIT': '',
#    'SORT': '190',
#    'SYSTEM': 'N'},
#   {'ID': '580',
#    'ENTITY_ID': 'DEAL_STAGE_2',
#    'STATUS_ID': 'C2:14',
#    'NAME': 'Не удалось связаться с клиентом',
#    'NAME_INIT': '',
#    'SORT': '190',
#    'SYSTEM': 'N',
#    'EXTRA': {'SEMANTICS': 'apology', 'COLOR': '#FF5752'}},
#   {'ID': '212',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': 'B24_APPLICATION',
#    'NAME': 'Заявка из приложения',
#    'NAME_INIT': '',
#    'SORT': '200',
#    'SYSTEM': 'N'},
#   {'ID': '550',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '31',
#    'NAME': 'initpro',
#    'NAME_INIT': '',
#    'SORT': '210',
#    'SYSTEM': 'N'},
#   {'ID': '582',
#    'ENTITY_ID': 'SOURCE',
#    'STATUS_ID': '32',
#    'NAME': 'TenderBot',
#    'NAME_INIT': '',
#    'SORT': '220',
#    'SYSTEM': 'N'}],
#  'total': 236,
#  'time': {'start': 1590585516.733838,
#   'finish': 1590585516.78196,
#   'duration': 0.04812192916870117,
#   'processing': 0.01635003089904785,
#   'date_start': '2020-05-27T16:18:36+03:00',
#   'date_finish': '2020-05-27T16:18:36+03:00'}}

# %% [raw]
# {'ID': '107',
# 'ENTITY_ID': 'DEAL_TYPE',
# 'STATUS_ID': 'SERVICES',
# 'NAME': 'Продажа услуги',
# 'NAME_INIT': '',
# 'SORT': '40',
# 'SYSTEM': 'N'}

# %% [raw]
# 'TYPE_ID': {'type': 'crm_status',
# 'isRequired': False,
# 'isReadOnly': False,
# 'isImmutable': False,
# 'isMultiple': False,
# 'isDynamic': False,
# 'statusType': 'DEAL_TYPE',
# 'title': 'Тип'}

# %%
def set_fields(title=None, type_id=None, category_id=None, stage_id=None, stage_semantic_id=None, is_new=None,
               is_recurring=None, is_return_customer=None, is_repeated_approach=None, probability=None,
               currency_id = None, opportunity = None, tax_value = None, company_id = None,  contact_id = None, 
               contanc_ids = None, quote_id = None, begin_date = None, close_date = None, is_opend = None, 
               is_closed = None, comments = None, assigned_by_id = None, created_by_id = None, modify_by_id = None, 
               date_create = None, date_modify = None, source_id = None, source_sedcription = None, lead_id = None, 
               additional_info = None, location_id = None, originator_id = None, origin_id = None, utm_source = None, 
               utm_campaign = None, utm_content = None, utm_term = None, uf_crm = None, uf_crm_city = None, 
               proposal_deposit = None, contract_deposit = None, cost_price = None, costs = None,
              ):
    
    fields = {
        "TITLE": title,  # Название
        "TYPE_ID": type_id,  # Тип
        "CATEGORY_ID": category_id,  # Направление
        "STAGE_ID": stage_id,  # Стадия сделки
        "STAGE_SEMANTIC_ID": stage_semantic_id,  # Группа стадии
        "IS_NEW": is_new,  # Новая сделка
        "IS_RECURRING": is_recurring,  # Регулярная сделка
        "IS_RETURN_CUSTOMER": is_return_customer,  # Повторная сделка
        "IS_REPEATED_APPROACH": is_repeated_approach,  # Повторное обращение
        "PROBABILITY": probability,  # Вероятность
        "CURRENCY_ID": currency_id,  # Валюта
        "OPPORTUNITY": opportunity,  # Сумма
        "TAX_VALUE": tax_value,  # Ставка налога
        "COMPANY_ID": company_id,  # Компания
        "CONTACT_ID": contact_id,  # Контакт
        "CONTACT_IDS": contanc_ids,  # Контакты
        "QUOTE_ID": quote_id,  # Предложение
        "BEGINDATE": begin_date,  # Дата начала
        "CLOSEDATE": close_date,  # Дата завершения
        "OPENED": is_opend,  # Доступна для всех
        "CLOSED": is_closed,  # Закрыта
        "COMMENTS": comments,  # Комментарий
        "ASSIGNED_BY_ID": assigned_by_id,  # Ответственный
        "CREATED_BY_ID": created_by_id,  # Кем создана
        "MODIFY_BY_ID": modify_by_id,  # Кем изменена
        "DATE_CREATE": date_create,  # Дата создания
        "DATE_MODIFY": date_modify,  # Дата изменения
        "SOURCE_ID": source_id,  # Источник
        "SOURCE_DESCRIPTION": source_sedcription,  # Дополнительно об источнике
        "LEAD_ID": lead_id,  # Лид
        "ADDITIONAL_INFO": additional_info,  # Дополнительная информация
        "LOCATION_ID": location_id,  # Местоположение
        "ORIGINATOR_ID": originator_id,  # Внешний источник
        "ORIGIN_ID": origin_id,  # Идентификатор элемента во внешнем источнике
        "UTM_SOURCE": utm_source,  # Тип трафика
        "UTM_CAMPAIGN":  utm_campaign,  # Обозначение рекламной кампании
        "UTM_CONTENT": utm_content,  # Содержание кампании
        "UTM_TERM": utm_term,  # Условие поиска кампании
        "UF_CRM_59F1D464C7CB3": uf_crm, # Номер документа
        "UF_CRM_CITY": uf_crm_city,  # Обеспечение заявки
        "UF_CRM_1548243578811": proposal_deposit,  # Обеспечение заявки
        "UF_CRM_1548243648878": contract_deposit,  # Обеспечение контракта
        "UF_CRM_1548243747417": cost_price,  # Себестоимость контракта
        "UF_CRM_1548245317652": costs,  # Расходы на подачу заявки специалистом
    }
        
    return dict(fields={x: y for x, y in fields.items() if y is not None},
               params={"REGISTER_SONET_EVENT": "Y"})
